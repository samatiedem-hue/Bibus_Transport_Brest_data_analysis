# %%
import pandas as pd
dfc = pd.ExcelFile("Bibus")
dfc.sheet_names
# Out:
# ['🚌 Trajets',
#  '📍 Arrêts',
#  '⚠️ Incidents',
#  '⭐ Satisfaction',
#  '🗺️ Lignes',
#  '📋 README']

# %%
trajets = pd.read_excel("Bibus", header=2)
trajets.head(15)
# Out:
#    ID_Trajet        Date Jour_Semaine     Mois Trimestre Est_Weekend Ligne  \
# 0    TR00001  2024-01-24    Wednesday  January        T1         Non    T1
# 1    TR00002  2024-05-16     Thursday      May        T2         Non    T2
# 2    TR00003  2024-01-29       Monday  January        T1         Non     4
# 3    TR00004  2024-10-14       Monday  October        T4         Non    10
# 4    TR00005  2024-03-22       Friday    March        T1         Non    T1
# 5    TR00006  2024-05-16     Thursday      May        T2         Non    T1
# 6    TR00007  2024-04-11     Thursday    April        T2         Non     3
# 7    TR00008  2024-06-06     Thursday     June        T2         Non     4
# 8    TR00009  2024-03-25       Monday    March        T1         Non     5
# 9    TR00010  2024-03-02     Saturday    March        T1         Oui     4
# 10   TR00011  2024-06-18      Tuesday     June        T2         Non     2
# 11   TR00012  2024-06-30       Sunday     June        T2         Oui     7
# 12   TR00013  2024-03-12      Tuesday    March        T1         Non     7
# 13   TR00014  2024-05-01    Wednesday      May        T2         Non     3
# 14   TR00015  2024-05-26       Sunday      May        T2         Oui     7
#
#       Type_Ligne                                   Nom_Ligne  \
# 0           tram  Tram: Porte de Gouesnou - Pont de l'Iroise
# 1           tram   Tram: Bertha von Suttner - Cavale Blanche
# 2     principale                     Kergaradec - Pontanézen
# 3   interurbaine             Brest Gare - Kersaint-Plabennec
# 4           tram  Tram: Porte de Gouesnou - Pont de l'Iroise
# 5           tram  Tram: Porte de Gouesnou - Pont de l'Iroise
# 6     principale                      Lambézellec - Bellevue
# 7     principale                     Kergaradec - Pontanézen
# 8     principale                Recouvrance - Cavale Blanche
# 9     principale                     Kergaradec - Pontanézen
# 10    principale                  Penn ar C'hleuz - Plouzané
# 11    secondaire                   Brest Centre - Saint-Marc
# 12    secondaire                   Brest Centre - Saint-Marc
# 13    principale                      Lambézellec - Bellevue
# 14    secondaire                   Brest Centre - Saint-Marc
#
#          Arret_Depart  ... Taux_Remplissage_Pct Distance_km Duree_Prevue_Min  \
# 0          Kergaradec  ...                 67.5         8.0               24
# 1         Landivisiau  ...                 33.8         5.1               15
# 2          Saint-Marc  ...                 73.3         3.7               11
# 3            Kersaint  ...                 88.9        16.7               50
# 4        Moulin Blanc  ...                 88.8        11.1               33
# 5   Porte de Gouesnou  ...                 82.5        12.7               38
# 6      Pen ar Creac'h  ...                 38.3        10.0               30
# 7           Kerangoff  ...                 63.3         7.1               21
# 8         Landivisiau  ...                 38.3         6.7               20
# 9     Plouzané Centre  ...                 46.7         3.2               10
# 10    Penn ar C'hleuz  ...                 70.0         4.7               14
# 11         Kergaradec  ...                 31.1         3.6               11
# 12            Arsenal  ...                104.4         8.2               25
# 13        Recouvrance  ...                 80.0        10.0               30
# 14          Kerangoff  ...                 46.7         6.8               20
#
#    Duree_Reelle_Min ID_Conducteur   ID_Bus Age_Bus_Ans         Meteo  \
# 0                26          C024  BUS0021           4       Nuageux
# 1                15          C018  BUS0072          11       Nuageux
# 2                12          C026  BUS0059           5  Pluie légère
# 3                56          C006  BUS0007           4       Nuageux
# 4                35          C001  BUS0015           2     Vent fort
# 5                45          C007  BUS0039           1    Ensoleillé
# 6                31          C002  BUS0015           2       Nuageux
# 7                22          C009  BUS0017           7       Nuageux
# 8                23          C043  BUS0048           4       Nuageux
# 9                11          C004  BUS0030          12  Pluie légère
# 10               15          C027  BUS0025           1   Pluie forte
# 11               10          C007  BUS0032           7  Pluie légère
# 12               35          C035  BUS0002           2    Ensoleillé
# 13               33          C025  BUS0034           8    Ensoleillé
# 14               22          C004  BUS0075          14       Nuageux
#
#              Incident  Note_Confort
# 0               Aucun           2.5
# 1               Aucun           3.7
# 2               Aucun           4.3
# 3               Aucun           2.3
# 4               Aucun           4.1
# 5   Incident voyageur           3.8
# 6        Trafic dense           4.1
# 7   Incident voyageur           4.7
# 8             Travaux           3.7
# 9               Aucun           3.6
# 10              Aucun           5.0
# 11              Aucun           4.6
# 12              Aucun           3.8
# 13              Aucun           3.7
# 14              Aucun           2.5
#
# [15 rows x 29 columns]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
trajets["Retard_Minutes"].hist(bins=20)
plt.title("Distribution des retards")
plt.xlabel("Retard (minuite)")
plt.ylabel("Nombre de trajets")
plt.show()
# le bins = 20 nous dit de découpé les données en 20 intervalles ou classe 
# les retard sont concentrer au tours d'une valeur

# %%
# Distribution du nombre de passegers
plt.figure(figsize=(8,5))
trajets["Nb_Passagers"].hist(bins=20)
plt.title("Distributions du nombre de passagers")
plt.xlabel("Nombre de passegers")
plt.ylabel("Nombre de trajets")
plt.show()

# %%
# Détections des valeurs extremes
#Des retards anormalement élevés
plt.figure(figsize = (8,5))
plt.boxplot(trajets["Retard_Minutes"])
plt.title("Boxplot des retards")
plt.show()

# %%
# Nombre de passagers
plt.figure(figsize=(8,5))
plt.boxplot(trajets["Nb_Passagers"])
plt.title("Boxplot du nombre de passagers")
plt.show()

# %%
# Répartition de la météo
trajets["Meteo"].value_counts().plot(kind="bar")
plt.title(" conditions Meteo")
plt.xlabel("Meteo")
plt.ylabel("Nb de Trajets")
plt.show()

# %%
# répartitions des tranches horraire
trajets["Tranche_Horaire"].value_counts().plot(kind="bar")
plt.title("Répartition des tranches horaires")
plt.xlabel("Tranche Ho")
plt.ylabel("Nombre de trajets")
plt.show()

# %%
trajets["Est_Weekend"].value_counts().plot(kind="bar")
plt.title("Trajets semaine vs week-end")
plt.show()

# %%
# retard selon la meteo
trajets.groupby("Meteo")["Retard_Minutes"].mean().plot(kind="bar")
plt.title("Retard moyen selon la meteo")
plt.ylabel("Retard moyens (minutes)")
plt.show()
